# %%
import pandas as pd
import numpy as np

# %%
df = pd.concat([
    pd.read_csv("hep_test.csv"),
    pd.read_csv("hep_train.csv"),
])

# %%
df = df.reset_index()
np.random.seed(0)
shuffled = df.reindex(np.random.permutation(df.index))
shuffled = shuffled.drop(["index"], axis=1)

# %%
shuffled.to_csv("shuffled_hep.csv", index=False)

# %%
df = pd.read_csv("../bigdata/hep.csv", nrows=100000)

# %%
df.describe()
# Out:
#              # label             f0             f1             f2  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.497750       0.017461      -0.003308      -0.001805
# std         0.499997       1.004085       0.997380       0.999689
# min         0.000000      -1.960403      -2.365090      -1.732055
# 25%         0.000000      -0.728879      -0.737964      -0.867752
# 50%         0.000000      -0.033449       0.002601      -0.001214
# 75%         1.000000       0.692568       0.727985       0.862435
# max         1.000000       3.967927       2.365098       1.732315
#
#                   f3             f4             f5             f6  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.006393       0.001364       0.001317       0.015582
# std         0.994326       1.000915       0.998474       0.984748
# min        -6.911899      -1.732132      -1.054221      -2.680325
# 25%        -0.615910      -0.867539      -1.054221      -0.752821
# 50%         0.020468       0.005495      -0.005984      -0.155548
# 75%         0.674854       0.869937       0.850488       0.767184
# max         3.270470       1.731973       4.482618       3.393760
#
#                   f7             f8      ...                  f18  \
# count  100000.000000  100000.000000      ...        100000.000000
# mean        0.006446      -0.006998      ...             0.013643
# std         0.994951       1.000466      ...             1.002497
# min        -2.757541      -1.732354      ...            -1.728158
# 25%        -0.695170      -0.876127      ...            -0.738951
# 50%         0.003944      -0.009743      ...            -0.086142
# 75%         0.708428       0.858111      ...             0.644354
# max         2.758526       1.731423      ...             4.859229
#
#                  f19            f20            f21            f22  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.002634       0.000862      -0.000319       0.007018
# std         1.003493       0.998796       0.999818       1.007444
# min        -2.281699      -1.731725      -0.573682      -3.439655
# 25%        -0.721219      -0.860305      -0.573682      -0.547766
# 50%        -0.000467      -0.001665      -0.573682      -0.165326
# 75%         0.727472       0.870213      -0.573682       0.472656
# max         2.282034       1.732690       1.743123       6.848585
#
#                  f23            f24            f25            f26  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.005903       0.004834      -0.005674       0.013145
# std         1.001776       1.004199       0.980509       0.980143
# min        -3.432950      -9.153657      -2.354402      -2.307665
# 25%        -0.514037      -0.354217      -0.692739      -0.792343
# 50%        -0.315910      -0.326397      -0.358943      -0.092331
# 75%         0.160957      -0.232259       0.470392       0.760057
# max         8.650244      12.965413       4.426124       3.970438
#
#                 mass
# count  100000.000000
# mean      999.292494
# std       353.157370
# min       499.999969
# 25%       750.000000
# 50%      1000.000000
# 75%      1250.000000
# max      1500.000000
#
# [8 rows x 29 columns]
