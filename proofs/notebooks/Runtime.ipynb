# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png' 
import numpy as np
import scipy
import scipy.special
import scipy.stats
import math
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import sklearn.linear_model

# %%
dfs = pd.read_csv("kernel_size_dim10.csv")
dfd = pd.read_csv("kernel_dim.csv")

# %%
plt.plot(dfs.sizes, dfs.kernels)

# %%
plt.plot(np.log(dfs.sizes), np.log(dfs.kernels))

# %%
m = sklearn.linear_model.LinearRegression().fit(X=np.log(dfs[["sizes"]]), y=np.log(dfs["kernels"]))
print(m.coef_)
# Out:
# [ 0.56104617]

# %%
dfs.plot(x="sizes", y="kernels")

# %%
plt.semilogx(dfs.sizes, dfs.kernels)

# %%
dfd.plot(x="dim",y="kernels")
